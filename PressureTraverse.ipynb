# %% [markdown]
# # Pressure Traverse- Revised Beggs and Brill Correlation

# %% [markdown]
# Importing psapy

# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import psapy.FluidProps
import psapy.BeggsandBrill as BB

# %%
import psapy.WoldesemayatandGhajar as WG

# %% [markdown]
# Input Data

# %%
oil_rate= 100
water_rate = 50
gor = 300
gas_grav = 0.65
oil_grav = 35
wtr_grav = 1.07
diameter=2.441
angle=90.0
thp= 150.0
tht=100.0
twf=150.0
depth = 5000
sample_size =51

def temp_gradient(t0,t1, depth):
    if depth==0:
        return 0
    else:
        return abs(t0-t1)/depth    

t_grad = temp_gradient(tht,twf, depth)
t_grad
# Out:
# 0.01

# %%
depths = np.linspace(0, depth, sample_size)

# %%
temps = tht + t_grad * depths

# %%
#def Pgrad(P, T, oil_rate, wtr_rate, Gor, gas_grav, oil_grav, wtr_grav, d, angle):


def pressure_traverse_bb(oil_rate):
    p=[]
    dpdz=[]
    dpdz_Wg = []
    for i in range(len(depths)):

        if i==0:
            p.append(thp)
        else:
            dz = (depths[i]-depths[i-1])
            pressure = p[i-1]+dz*dpdz[i-1]
            p.append(pressure)

        dpdz_step = BB.Pgrad(p[i], temps[i], oil_rate, water_rate, gor, gas_grav, oil_grav, wtr_grav, diameter, angle) 
        dpdz.append(dpdz_step)
        
    return p, dpdz
def pressure_traverse_WG(oil_rate):
    p=[]
    dpdz=[]
    for i in range(len(depths)):

        if i==0:
            p.append(thp)
        else:
            dz = (depths[i]-depths[i-1])
            pressure = p[i-1]+dz*dpdz[i-1]
            p.append(pressure)

        dpdz_step_WG = WG.Pgrad(p[i], temps[i], oil_rate, water_rate, gor, gas_grav, oil_grav, wtr_grav, diameter, angle)
        dpdz.append(dpdz_step_WG)
        
    return p, dpdz
p_bb, dpdz = pressure_traverse_bb(oil_rate)
p_wg, dpdz = pressure_traverse_WG(oil_rate)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# d:\Training Pool\Python For Oil and Gas Industry\Python Database Training\Full DB Creation\production_systems_analysis\PressureTraverse.ipynb Cell 9 line 3
#      <a href='vscode-notebook-cell:/d%3A/Training%20Pool/Python%20For%20Oil%20and%20Gas%20Industry/Python%20Database%20Training/Full%20DB%20Creation/production_systems_analysis/PressureTraverse.ipynb#X10sZmlsZQ%3D%3D?line=35'>36</a>     return p, dpdz
#      <a href='vscode-notebook-cell:/d%3A/Training%20Pool/Python%20For%20Oil%20and%20Gas%20Industry/Python%20Database%20Training/Full%20DB%20Creation/production_systems_analysis/PressureTraverse.ipynb#X10sZmlsZQ%3D%3D?line=36'>37</a> p_bb, dpdz = pressure_traverse_bb(oil_rate)
# ---> <a href='vscode-notebook-cell:/d%3A/Training%20Pool/Python%20For%20Oil%20and%20Gas%20Industry/Python%20Database%20Training/Full%20DB%20Creation/production_systems_analysis/PressureTraverse.ipynb#X10sZmlsZQ%3D%3D?line=37'>38</a> p_wg, dpdz = pressure_traverse_WG(oil_rate)
#
# d:\Training Pool\Python For Oil and Gas Industry\Python Database Training\Full DB Creation\production_systems_analysis\PressureTraverse.ipynb Cell 9 line 3
#      <a href='vscode-notebook-cell:/d%3A/Training%20Pool/Python%20For%20Oil%20and%20Gas%20Industry/Python%20Database%20Training/Full%20DB%20Creation/production_systems_analysis/PressureTraverse.ipynb#X10sZmlsZQ%3D%3D?line=29'>30</a>         pressure = p[i-1]+dz*dpdz[i-1]
#      <a href='vscode-notebook-cell:/d%3A/Training%20Pool/Python%20For%20Oil%20and%20Gas%20Industry/Python%20Database%20Training/Full%20DB%20Creation/production_systems_analysis/PressureTraverse.ipynb#X10sZmlsZQ%3D%3D?line=30'>31</a>         p.append(pressure)
# ---> <a href='vscode-notebook-cell:/d%3A/Training%20Pool/Python%20For%20Oil%20and%20Gas%20Industry/Python%20Database%20Training/Full%20DB%20Creation/production_systems_analysis/PressureTraverse.ipynb#X10sZmlsZQ%3D%3D?line=32'>33</a>     dpdz_step_WG = WG.Pgrad(p[i], temps[i], oil_rate, water_rate, gor, gas_grav, oil_grav, wtr_grav, diameter, angle)
#      <a href='vscode-notebook-cell:/d%3A/Training%20Pool/Python%20For%20Oil%20and%20Gas%20Industry/Python%20Database%20Training/Full%20DB%20Creation/production_systems_analysis/PressureTraverse.ipynb#X10sZmlsZQ%3D%3D?line=33'>34</a>     dpdz.append(dpdz_step_WG)
#      <a href='vscode-notebook-cell:/d%3A/Training%20Pool/Python%20For%20Oil%20and%20Gas%20Industry/Python%20Database%20Training/Full%20DB%20Creation/production_systems_analysis/PressureTraverse.ipynb#X10sZmlsZQ%3D%3D?line=35'>36</a> return p, dpdz
#
# File d:\Training Pool\Python For Oil and Gas Industry\Python Database Training\Full DB Creation\production_systems_analysis\psapy\WoldesemayatandGhajar.py:80, in Pgrad(P, T, oil_rate, wtr_rate, Gor, gas_grav, oil_grav, wtr_grav, d, angle)
#      77 L3 = 0.1 * laml ** -1.4516
#      78 L4 = 0.5 * laml ** -6.738
# ---> 80 regime = Flow_regime(Nfr, laml, L1, L2, L3, L4)
#      82 #Calculate holdups
#      83 # Using woldesmayat and Ghajar
#      84 if (regime == 2):
#
# File d:\Training Pool\Python For Oil and Gas Industry\Python Database Training\Full DB Creation\production_systems_analysis\psapy\WoldesemayatandGhajar.py:151, in Flow_regime(Nfr, laml, L1, L2, L3, L4)
#     147 if (((laml < 0.4) and (Nfr >= L1)) or ((laml >= 0.4) and (Nfr > L4))):
#     148     regime = 4
# --> 151 return regime
#
# UnboundLocalError: local variable 'regime' referenced before assignment

# %%
scatter =plt.scatter(p, depths)
ax = scatter.axes
ax.invert_yaxis()
plt.xlabel('Pressure')
plt.ylabel('Depth')
plt.show()

# %%
oil_rates=[100,200,300]

# %%
for r in oil_rates:
    p, dpdz =pressure_traverse(r)
    scatter =plt.scatter(p, depths)
ax = scatter.axes
ax.invert_yaxis()
plt.xlabel('Pressure')
plt.ylabel('Depth')
plt.show()

# %%
def vlp(rates):
    bhps =[]
    for q in rates:
        p, dpdz = pressure_traverse(q)
        bhp = p[-1]
        bhps.append(bhp)
    return bhps

rates = np.linspace(100, 5000, 50)
bhps = vlp(rates)
plt.plot(rates, bhps, '-')
plt.xlabel('Rate')
plt.ylabel('Pressure')
plt.show()
